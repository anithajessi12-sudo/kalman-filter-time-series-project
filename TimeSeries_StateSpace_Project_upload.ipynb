# %% [markdown]
# # Time Series State-Space Project
# This notebook runs EDA and models.

# %%
import pandas as pd

df = pd.read_csv('data/time_series_dataset.csv', parse_dates=['date']).set_index('date')
df.head()

# %%
print('Plotting')
import matplotlib.pyplot as plt
plt.plot(df.index, df['value'])
plt.show()
